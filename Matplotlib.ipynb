# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
# ans.
#
# ### **What is Matplotlib?**
#
# Matplotlib is a **popular data visualization library in Python** that provides tools for creating static, animated, and interactive plots. It is widely used in data science, machine learning, and scientific computing for presenting data graphically.
#
# ### **Why is it used?**
#
# Matplotlib is used for:
#
# * Visualizing data to identify trends and patterns.
# * Creating publication-quality graphs and charts.
# * Customizing plots (labels, legends, colors, styles).
# * Supporting multiple backends and platforms.
# * Integration with other libraries like NumPy and pandas.
#
# ### **Five plots that can be plotted using the Pyplot module of Matplotlib:**
#
# 1. **Line Plot**
# 2. **Bar Plot**
# 3. **Histogram**
# 4. **Scatter Plot**
# 5. **Pie Chart**
#
# The `pyplot` module (often imported as `plt`) provides a MATLAB-like interface for easy and quick plotting.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.
#
#
# ans. A scatter plot is a type of plot that displays values for two numerical variables using dots. It helps visualize the relationship or correlation between two datasets. Each dot in the scatter plot represents an observation with an x and y coordinate.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating data
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Creating the scatter plot
plt.scatter(x, y, color='blue', marker='o')

# Adding title and labels
plt.title('Scatter Plot of Random Data')
plt.xlabel('X values')
plt.ylabel('Y values')

# Show the plot
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Line data
x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.figure(figsize=(10, 8))

# Plot 1
plt.subplot(2, 2, 1)  # (rows, columns, position)
plt.plot(x, y1, color='blue')
plt.title('Line 1')

# Plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2, color='green')
plt.title('Line 2')

# Plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3, color='red')
plt.title('Line 3')

# Plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4, color='purple')
plt.title('Line 4')

# Add spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)
#
#
# ans. A bar plot (or bar chart) is a graph that represents categorical data with rectangular bars. The length or height of each bar is proportional to the value it represents.
#
# Why is it used?
# To compare values across different categories.
#
# To visualize frequencies, counts, or any measurable variable.
#
# It’s useful for qualitative data analysis.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical Bar Plot
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.bar(company, profit, color='skyblue')
plt.title('Company Profits (Vertical)')
plt.xlabel('Company')
plt.ylabel('Profit')

# Horizontal Bar Plot
plt.subplot(1, 2, 2)
plt.barh(company, profit, color='orange')
plt.title('Company Profits (Horizontal)')
plt.xlabel('Profit')
plt.ylabel('Company')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)
#
#
# ans. A box plot (or box-and-whisker plot) is a graphical representation of the distribution of a dataset. It displays:
#
# Minimum
#
# First Quartile (Q1)
#
# Median (Q2)
#
# Third Quartile (Q3)
#
# Maximum
#
# And possible outliers
#
# Why is it used?
# To understand the spread, skewness, and presence of outliers in the data.
#
# To compare distributions between multiple datasets.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Plotting the box plot
plt.figure(figsize=(6, 6))
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'], patch_artist=True)

plt.title('Box Plot Comparison')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-3-5cd104631a46>:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'], patch_artist=True)
